# %%
import csv
import http.client
import json
import pandas

conn = http.client.HTTPSConnection("opendata.aemet.es")
headers = {'cache-control': "no-cache"}
api_key="eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqaGVycmFuem1hQHVvYy5lZHUiLCJqdGkiOiJhOGY5YTFmYy02ZWFjLTRmNWItYWM5My01MDg3OWJhMGY1YzUiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTU4NTM5MTQzMSwidXNlcklkIjoiYThmOWExZmMtNmVhYy00ZjViLWFjOTMtNTA4NzliYTBmNWM1Iiwicm9sZSI6IiJ9.dZ4nTXq0e8hbjW7lScXxjIDiBO_fcR_s-ITE2u5ohaY"

years=list(range(2011, 2013))
months=list(range(1,13))
days=[31,29,31,30,31,30,31,31,30,31,30,31]
ids=["2117D","2444","2331","2946X","2630X","2661","9051","2503X","9111","2030","2401","1549","2870","2465","2614"]

for year in years:
    for month in months:

        print("Descargando datos... / Mes: ",month," Año: ",year)
        conn.request("GET",
                    "/opendata/api/valores/climatologicos/diarios/datos/fechaini/"+
                    str(year)+"-"+str(month)
                    +"-01T00%3A00%3A00UTC/fechafin/"+str(year)+"-"+
                    str(month)+"-"+str(days[month-1])
  #                      +"T23%3A59%3A59UTC/estacion/"+str(i)+"/?api_key="+
                    +"T23%3A59%3A59UTC/estacion/2117D/?api_key="+ 
                    api_key, headers=headers)

        res=conn.getresponse()
        json_response=res.read()
        dict_response=json.loads(json_response.decode("ISO-8859-1"))
        conn.request("GET", dict_response['datos'], headers=headers)

        res=conn.getresponse()
        json_data=res.read()


        df=pandas.read_json(json_data, encoding="ISO-8859-1")
        data_csv=df.to_csv()

        fileName="datos_clima_" + str(year) + "_" + str(month) + ".csv"
        with open(fileName, "w") as outfile:
            outfile.write(data_csv)
# Out:
# Descargando datos... / Mes:  1  Año:  2011
# Descargando datos... / Mes:  2  Año:  2011
# Descargando datos... / Mes:  3  Año:  2011
# Descargando datos... / Mes:  4  Año:  2011
# Descargando datos... / Mes:  5  Año:  2011
# Descargando datos... / Mes:  6  Año:  2011
# Descargando datos... / Mes:  7  Año:  2011
# Descargando datos... / Mes:  8  Año:  2011
# Descargando datos... / Mes:  9  Año:  2011
# Descargando datos... / Mes:  10  Año:  2011
# Descargando datos... / Mes:  11  Año:  2011
# Descargando datos... / Mes:  12  Año:  2011
# Descargando datos... / Mes:  1  Año:  2012
# Descargando datos... / Mes:  2  Año:  2012
# Descargando datos... / Mes:  3  Año:  2012
# Descargando datos... / Mes:  4  Año:  2012
# Descargando datos... / Mes:  5  Año:  2012
# Descargando datos... / Mes:  6  Año:  2012
# Descargando datos... / Mes:  7  Año:  2012
# Descargando datos... / Mes:  8  Año:  2012
# Descargando datos... / Mes:  9  Año:  2012
# Descargando datos... / Mes:  10  Año:  2012
# ...

# %%
import csv
import http.client
import json
import pandas

conec = http.client.HTTPSConnection("opendata.aemet.es")
headers = {'cache-control': "no-cache"}
api_key="eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqaGVycmFuem1hQHVvYy5lZHUiLCJqdGkiOiJhOGY5YTFmYy02ZWFjLTRmNWItYWM5My01MDg3OWJhMGY1YzUiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTU4NTM5MTQzMSwidXNlcklkIjoiYThmOWExZmMtNmVhYy00ZjViLWFjOTMtNTA4NzliYTBmNWM1Iiwicm9sZSI6IiJ9.dZ4nTXq0e8hbjW7lScXxjIDiBO_fcR_s-ITE2u5ohaY"

years=list(range(2011, 2012))
months=list(range(1,13))
days=[31,29,31,30,31,30,31,31,30,31,30,31]
ids=["2117D","2444","2331","2946X","2235U","2630X","2661","9051","2503X","9111","2030","2401","1549","2870","2465","2614"]

for year in years:
    for month in months:
        for i in ids:
            print("Descargando datos de estacion:",i," Mes:",month," Año:",year)
            conec.request("GET",
                        "/opendata/api/valores/climatologicos/diarios/datos/fechaini/"+
                        str(year)+"-"+str(month)
                        +"-01T00:00:00UTC/fechafin/"+str(year)+"-"+
                        str(month)+"-"+str(days[month-1])
                        +"T23:59:59UTC/estacion/"+str(i)+"/?api_key="+
                        api_key, headers=headers)

            res=conec.getresponse()
            json_response=res.read()
            dict_response=json.loads(json_response.decode("ISO-8859-1"))
            conec.request("GET", dict_response['datos'], headers=headers)

            res=conec.getresponse()
            json_data=res.read()


            df=pandas.read_json(json_data, encoding="ISO-8859-1")
            data_csv=df.to_csv()

            fileName="datos_clima_" + str(i) + "_" + str(year) + "_" + str(month) + ".csv"
            with open(fileName, "w") as outfile:
                outfile.write(data_csv)
# Out:
# Descargando datos de estacion: 2117D  Mes: 1  Año: 2011
# Descargando datos de estacion: 2444  Mes: 1  Año: 2011
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-408836a0a2c8> in <module>
#      34
#      35
# ---> 36             df=pandas.read_json(json_data, encoding="utf-8")
#      37             data_csv=df.to_csv()
#      38
#
# c:\users\juan\appdata\local\programs\python\python37\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# c:\users\juan\appdata\local\programs\python\python37\lib\site-packages\pandas\io\json\json.py in read(self)
# ...

# %%
import csv
import http.client
import json
import pandas

conn = http.client.HTTPSConnection("opendata.aemet.es")
headers = {'cache-control': "no-cache"}
api_key="eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqaGVycmFuem1hQHVvYy5lZHUiLCJqdGkiOiJhOGY5YTFmYy02ZWFjLTRmNWItYWM5My01MDg3OWJhMGY1YzUiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTU4NTM5MTQzMSwidXNlcklkIjoiYThmOWExZmMtNmVhYy00ZjViLWFjOTMtNTA4NzliYTBmNWM1Iiwicm9sZSI6IiJ9.dZ4nTXq0e8hbjW7lScXxjIDiBO_fcR_s-ITE2u5ohaY"

years=list(range(2011, 2013))
months=list(range(1,13))
days=[31,29,31,30,31,30,31,31,30,31,30,31]
ids=['2117D',2444,2331,'2946X','2630X',2661,9051,'2503X',9111,2030,2401,1549,2870,2465,2614]

for year in years:
    for month in months:
        for i in ids:
            print("Descargando datos de estacion:",i," Mes:",month," Año:",year)
            conn.request("GET",
                        "/opendata/api/valores/climatologicos/diarios/datos/fechaini/"+
                        str(year)+"-"+str(month)
                        +"-01T00%3A00%3A00UTC/fechafin/"+str(year)+"-"+
                        str(month)+"-"+str(days[month-1])
                        +"T23%3A59%3A59UTC/estacion/"+str(i)+"/?api_key="+
                       # +"T23%3A59%3A59UTC/estacion/2117D/?api_key="+ 
                        api_key, headers=headers)

            res=conn.getresponse()
            json_response=res.read()
            dict_response=json.loads(json_response.decode("ISO-8859-1"))
            conn.request("GET", dict_response['datos'], headers=headers)

            res=conn.getresponse()
            json_data=res.read()


            df=pandas.read_json(json_data, encoding="ISO-8859-1")
            data_csv=df.to_csv()

            fileName="datos_clima_" + str(i) + "_" + str(year) + "_" + str(month) + ".csv"
            with open(fileName, "w") as outfile:
                outfile.write(data_csv)
# Out:
# Descargando datos de estacion: 2117D  Mes: 1  Año: 2011
# Descargando datos de estacion: 2444  Mes: 1  Año: 2011
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-32a0b5e34875> in <module>
#      35
#      36
# ---> 37             df=pandas.read_json(json_data, encoding="ISO-8859-1")
#      38             data_csv=df.to_csv()
#      39
#
# c:\users\juan\appdata\local\programs\python\python37\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# c:\users\juan\appdata\local\programs\python\python37\lib\site-packages\pandas\io\json\json.py in read(self)
# ...

# %%
import csv
import http.client
import json
import pandas

conn = http.client.HTTPSConnection("opendata.aemet.es")
headers = {'cache-control': "no-cache"}
api_key="eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqaGVycmFuem1hQHVvYy5lZHUiLCJqdGkiOiJhOGY5YTFmYy02ZWFjLTRmNWItYWM5My01MDg3OWJhMGY1YzUiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTU4NTM5MTQzMSwidXNlcklkIjoiYThmOWExZmMtNmVhYy00ZjViLWFjOTMtNTA4NzliYTBmNWM1Iiwicm9sZSI6IiJ9.dZ4nTXq0e8hbjW7lScXxjIDiBO_fcR_s-ITE2u5ohaY"

years=list(range(2014, 2019))
months=list(range(1,13))
days=[31,29,31,30,31,30,31,31,30,31,30,31]

#ids=[2117D,2331,2946X,2630X,9051,2503X,9111,2030,2400E,1549,2870,2465,2614]

#2117D=Aranda de Duero -> Aranda de Duero 2 (1)
#2331=Burgos -> Burgos1 (1), Burgos4 (4)
#2946X=El Maillo (2) *

#2630X=La Robla   FALTAN DATOS
#9051=Medina de Pomar  FALTAN DATOS
#2503X=Medina del Campo  FALTAN DATOS
#9111=Miranda de Ebro *  FALTAN DATOS

#2030=Soria -> Muriel de la fuente (2), Soria (1)
#2400E=Palencia -> Palencia 3 (1), Renault4 (3)
#1549=Ponferrada -> Ponferrada4 (4), C.T.Compostilla-Cortiguera (3), C.T.Compostilla-Congosto (3)
#2870=Salamanca -> Salamanca5 (1), Salamanca6 (4)
#2465=Segovia -> Segovia 2 (1)
#2614=Zamora -> Zamora 2 (1)





for year in years:
    for month in months:

        estacion='2444'

        print("Descargando datos de estacion:",estacion," Mes:",month," Año:",year)
        conn.request("GET",
                    "/opendata/api/valores/climatologicos/diarios/datos/fechaini/"+
                    str(year)+"-"+str(month)
                    +"-01T00%3A00%3A00UTC/fechafin/"+str(year)+"-"+
                    str(month)+"-"+str(days[month-1])
                    +"T23%3A59%3A59UTC/estacion/"+str(estacion)+"/?api_key="+
                   # +"T23%3A59%3A59UTC/estacion/2117D/?api_key="+ 
                    api_key, headers=headers)

        res=conn.getresponse()
        json_response=res.read()
        dict_response=json.loads(json_response.decode("ISO-8859-1"))
        conn.request("GET", dict_response['datos'], headers=headers)

        res=conn.getresponse()
        json_data=res.read()


        df=pandas.read_json(json_data, encoding="ISO-8859-1")
        data_csv=df.to_csv()

        fileName="datos_clima_" + str(estacion) + "_"  + str(year) + "_" + str(month) + ".csv"
        with open(fileName, "w") as outfile:
            outfile.write(data_csv)
# Out:
# Descargando datos de estacion: 2444  Mes: 1  Año: 2014
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-773567747c9b> in <module>
#      58
#      59
# ---> 60         df=pandas.read_json(json_data, encoding="ISO-8859-1")
#      61         data_csv=df.to_csv()
#      62
#
# c:\users\juan\appdata\local\programs\python\python37\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# c:\users\juan\appdata\local\programs\python\python37\lib\site-packages\pandas\io\json\json.py in read(self)
#     527             )
#     528         else:
# ...
